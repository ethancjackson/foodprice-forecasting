# %%
import pandas as pd
pd.set_option('precision', 3)
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
import os
import numpy as np

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

import mxnet as mx
from gluonts.model.n_beats import NBEATSEnsembleEstimator
from gluonts.mx import Trainer
from gluonts.dataset.common import ListDataset
from gluonts.evaluation import make_evaluation_predictions

# %%
"""
Set sample rate. In this notebook, all data will be resampled at the chosen frequency.
'MS' : Monthly (Month Start)
'W' : Weekly
'D' : Daily
"""

year_period = {'MS': 12, 'W': 52, 'D': 365}
frequency = 'MS'
one_year = year_period[frequency]
output_path = "./output/nbeatsfredvars_202110"
if not os.path.exists(output_path):
    os.mkdir(output_path)

# %% [markdown]
# ## Load Data From File

# %%
foodprice_df = pd.read_csv("./all_data.csv", index_col=0)
foodprice_df = foodprice_df.set_index(pd.DatetimeIndex(foodprice_df.index))
foodprice_df
# Out:
#             Bakery and cereal products (excluding baby food)  \
# 1986-01-01                                              69.3
# 1986-02-01                                              70.3
# 1986-03-01                                              70.6
# 1986-04-01                                              71.3
# 1986-05-01                                              71.2
# ...                                                      ...
# 2021-06-01                                             157.7
# 2021-07-01                                             157.9
# 2021-08-01                                             158.5
# 2021-09-01                                             158.1
# 2021-10-01                                             159.3
#
#             Dairy products and eggs  Fish, seafood and other marine products  \
# 1986-01-01                     70.9                                     60.6
# 1986-02-01                     70.8                                     61.3
# 1986-03-01                     71.1                                     61.3
# 1986-04-01                     71.0                                     61.4
# 1986-05-01                     71.4                                     61.9
# ...                             ...                                      ...
# 2021-06-01                    145.3                                    146.2
# 2021-07-01                    146.4                                    146.6
# 2021-08-01                    148.3                                    146.8
# 2021-09-01                    148.0                                    147.1
# 2021-10-01                    146.6                                    149.3
#
#             Food purchased from restaurants   Food  \
# 1986-01-01                             59.1   67.3
# 1986-02-01                             59.1   66.9
# 1986-03-01                             59.3   67.0
# 1986-04-01                             59.7   67.7
# 1986-05-01                             59.9   68.2
# ...                                     ...    ...
# 2021-06-01                            163.9  156.8
# 2021-07-01                            165.2  157.6
# 2021-08-01                            165.9  158.0
# 2021-09-01                            165.9  158.5
# 2021-10-01                            167.1  159.2
#
#             Fruit, fruit preparations and nuts   Meat  \
# 1986-01-01                                76.0   65.1
# 1986-02-01                                77.6   64.2
# 1986-03-01                                79.2   64.2
# 1986-04-01                                82.2   63.6
# 1986-05-01                                83.5   64.0
# ...                                        ...    ...
# 2021-06-01                               144.5  176.7
# 2021-07-01                               141.7  180.9
# 2021-08-01                               142.5  182.1
# 2021-09-01                               141.5  184.8
# 2021-10-01                               141.7  187.1
#
#             Other food products and non-alcoholic beverages  \
# 1986-01-01                                             77.5
# 1986-02-01                                             78.1
# 1986-03-01                                             78.6
# 1986-04-01                                             79.5
# 1986-05-01                                             79.8
# ...                                                     ...
# 2021-06-01                                            142.2
# 2021-07-01                                            141.9
# 2021-08-01                                            141.7
# 2021-09-01                                            144.3
# 2021-10-01                                            144.4
#
#             Vegetables and vegetable preparations  DEXCAUS  ...  \
# 1986-01-01                                   76.0    1.392  ...
# 1986-02-01                                   68.4    1.392  ...
# 1986-03-01                                   66.2    1.392  ...
# 1986-04-01                                   71.1    1.392  ...
# 1986-05-01                                   75.3    1.377  ...
# ...                                           ...      ...  ...
# 2021-06-01                                  153.4    1.203  ...
# 2021-07-01                                  154.8    1.240  ...
# 2021-08-01                                  152.2    1.251  ...
# 2021-09-01                                  150.0    1.262  ...
# 2021-10-01                                  149.4    1.266  ...
#
#             XTIMVA01CAM657S  XTIMVA01CAM659S  XTIMVA01CAM664N  \
# 1986-01-01            3.644           12.051        9.368e+09
# 1986-02-01            1.965           16.745        9.495e+09
# 1986-03-01          -11.565            1.655        8.803e+09
# 1986-04-01           13.334           10.821        1.034e+10
# 1986-05-01           -4.236            6.160        9.598e+09
# ...                     ...              ...              ...
# 2021-06-01           -1.087           31.561        5.159e+10
# 2021-07-01            1.990           18.580        5.106e+10
# 2021-08-01           -2.312           14.723        5.245e+10
# 2021-09-01           -3.461            8.557        5.080e+10
# 2021-10-01           -3.461            8.557        5.080e+10
#
#             XTIMVA01CAM664S  XTIMVA01CAM667S  XTNTVA01CAM664N  \
# 1986-01-01        9.496e+09        6.749e+09        6.906e+08
# 1986-02-01        9.632e+09        6.881e+09       -9.880e+07
# 1986-03-01        8.529e+09        6.085e+09        9.138e+08
# 1986-04-01        9.569e+09        6.897e+09        3.470e+08
# 1986-05-01        9.091e+09        6.605e+09        7.013e+08
# ...                     ...              ...              ...
# 2021-06-01        4.979e+10        4.075e+10        3.661e+09
# 2021-07-01        5.205e+10        4.156e+10        3.780e+08
# 2021-08-01        5.115e+10        4.060e+10        1.300e+09
# 2021-09-01        4.965e+10        3.920e+10        1.561e+09
# 2021-10-01        4.965e+10        3.920e+10        1.561e+09
#
#             XTNTVA01CAM664S  XTNTVA01CAM667S   TOTALNS   TOTALSL
# 1986-01-01        1.052e+09        7.479e+08   607.369   605.703
# 1986-02-01        1.539e+08        1.099e+08   605.807   610.678
# 1986-03-01        9.079e+08        6.478e+08   606.799   613.377
# 1986-04-01        6.563e+08        4.730e+08   614.367   619.658
# 1986-05-01        6.893e+08        5.008e+08   621.915   625.820
# ...                     ...              ...       ...       ...
# 2021-06-01        3.111e+09        2.546e+09  4259.604  4307.137
# 2021-07-01        1.129e+09        9.018e+08  4276.202  4323.730
# 2021-08-01        2.674e+09        2.123e+09  4316.303  4337.489
# 2021-09-01        2.277e+09        1.798e+09  4346.662  4367.402
# 2021-10-01        2.277e+09        1.798e+09  4346.662  4367.402
#
# [430 rows x 332 columns]

# %% [markdown]
# ## Fitting and Evaluating a Single NBEATS Model: Example Using All Food Prices

# %%
N = foodprice_df.shape[1]
T = foodprice_df.shape[0]
prediction_length = 18
freq = "MS"
dataset = foodprice_df.T.values
start = pd.Timestamp("2016-07-01")

# %%
dataset_df = foodprice_df.T
dataset_df
# Out:
#                                                   1986-01-01  1986-02-01  \
# Bakery and cereal products (excluding baby food)   6.930e+01   7.030e+01
# Dairy products and eggs                            7.090e+01   7.080e+01
# Fish, seafood and other marine products            6.060e+01   6.130e+01
# Food purchased from restaurants                    5.910e+01   5.910e+01
# Food                                               6.730e+01   6.690e+01
# ...                                                      ...         ...
# XTNTVA01CAM664N                                    6.906e+08  -9.880e+07
# XTNTVA01CAM664S                                    1.052e+09   1.539e+08
# XTNTVA01CAM667S                                    7.479e+08   1.099e+08
# TOTALNS                                            6.074e+02   6.058e+02
# TOTALSL                                            6.057e+02   6.107e+02
#
#                                                   1986-03-01  1986-04-01  \
# Bakery and cereal products (excluding baby food)   7.060e+01   7.130e+01
# Dairy products and eggs                            7.110e+01   7.100e+01
# Fish, seafood and other marine products            6.130e+01   6.140e+01
# Food purchased from restaurants                    5.930e+01   5.970e+01
# Food                                               6.700e+01   6.770e+01
# ...                                                      ...         ...
# XTNTVA01CAM664N                                    9.138e+08   3.470e+08
# XTNTVA01CAM664S                                    9.079e+08   6.563e+08
# XTNTVA01CAM667S                                    6.478e+08   4.730e+08
# TOTALNS                                            6.068e+02   6.144e+02
# TOTALSL                                            6.134e+02   6.197e+02
#
#                                                   1986-05-01  1986-06-01  \
# Bakery and cereal products (excluding baby food)   7.120e+01   7.110e+01
# Dairy products and eggs                            7.140e+01   7.110e+01
# Fish, seafood and other marine products            6.190e+01   6.200e+01
# Food purchased from restaurants                    5.990e+01   6.000e+01
# Food                                               6.820e+01   6.840e+01
# ...                                                      ...         ...
# XTNTVA01CAM664N                                    7.013e+08   5.973e+08
# XTNTVA01CAM664S                                    6.893e+08   5.314e+08
# XTNTVA01CAM667S                                    5.008e+08   3.823e+08
# TOTALNS                                            6.219e+02   6.279e+02
# TOTALSL                                            6.258e+02   6.301e+02
#
#                                                   1986-07-01  1986-08-01  \
# Bakery and cereal products (excluding baby food)   7.170e+01   7.190e+01
# Dairy products and eggs                            7.130e+01   7.150e+01
# Fish, seafood and other marine products            6.220e+01   6.270e+01
# Food purchased from restaurants                    6.060e+01   6.090e+01
# Food                                               6.920e+01   6.950e+01
# ...                                                      ...         ...
# XTNTVA01CAM664N                                   -4.890e+08   9.390e+07
# XTNTVA01CAM664S                                   -9.670e+07   2.959e+08
# XTNTVA01CAM667S                                   -7.004e+07   2.131e+08
# TOTALNS                                            6.336e+02   6.405e+02
# TOTALSL                                            6.352e+02   6.389e+02
#
#                                                   1986-09-01  1986-10-01  ...  \
# Bakery and cereal products (excluding baby food)   7.170e+01   7.110e+01  ...
# Dairy products and eggs                            7.180e+01   7.180e+01  ...
# Fish, seafood and other marine products            6.310e+01   6.360e+01  ...
# Food purchased from restaurants                    6.090e+01   6.130e+01  ...
# Food                                               6.990e+01   7.020e+01  ...
# ...                                                      ...         ...  ...
# XTNTVA01CAM664N                                    1.542e+09   1.262e+09  ...
# XTNTVA01CAM664S                                    1.222e+09   1.165e+09  ...
# XTNTVA01CAM667S                                    8.806e+08   8.390e+08  ...
# TOTALNS                                            6.499e+02   6.567e+02  ...
# TOTALSL                                            6.460e+02   6.538e+02  ...
#
#                                                   2021-01-01  2021-02-01  \
# Bakery and cereal products (excluding baby food)   1.542e+02   1.571e+02
# Dairy products and eggs                            1.416e+02   1.431e+02
# Fish, seafood and other marine products            1.434e+02   1.439e+02
# Food purchased from restaurants                    1.626e+02   1.629e+02
# Food                                               1.550e+02   1.556e+02
# ...                                                      ...         ...
# XTNTVA01CAM664N                                    3.784e+09   2.126e+09
# XTNTVA01CAM664S                                    2.094e+09   1.701e+09
# XTNTVA01CAM667S                                    1.646e+09   1.339e+09
# TOTALNS                                            4.177e+03   4.166e+03
# TOTALSL                                            4.183e+03   4.204e+03
#
#                                                   2021-03-01  2021-04-01  \
# Bakery and cereal products (excluding baby food)   1.568e+02   1.562e+02
# Dairy products and eggs                            1.449e+02   1.461e+02
# Fish, seafood and other marine products            1.449e+02   1.451e+02
# Food purchased from restaurants                    1.626e+02   1.632e+02
# Food                                               1.555e+02   1.554e+02
# ...                                                      ...         ...
# XTNTVA01CAM664N                                   -7.842e+08  -8.295e+08
# XTNTVA01CAM664S                                   -1.682e+08   1.307e+09
# XTNTVA01CAM667S                                   -1.338e+08   1.045e+09
# TOTALNS                                            4.167e+03   4.186e+03
# TOTALSL                                            4.223e+03   4.239e+03
#
#                                                   2021-05-01  2021-06-01  \
# Bakery and cereal products (excluding baby food)   1.578e+02   1.577e+02
# Dairy products and eggs                            1.466e+02   1.453e+02
# Fish, seafood and other marine products            1.476e+02   1.462e+02
# Food purchased from restaurants                    1.635e+02   1.639e+02
# Food                                               1.566e+02   1.568e+02
# ...                                                      ...         ...
# XTNTVA01CAM664N                                   -3.348e+08   3.661e+09
# XTNTVA01CAM664S                                   -4.467e+08   3.111e+09
# XTNTVA01CAM667S                                   -3.685e+08   2.546e+09
# TOTALNS                                            4.227e+03   4.260e+03
# TOTALSL                                            4.272e+03   4.307e+03
#
#                                                   2021-07-01  2021-08-01  \
# Bakery and cereal products (excluding baby food)   1.579e+02   1.585e+02
# Dairy products and eggs                            1.464e+02   1.483e+02
# Fish, seafood and other marine products            1.466e+02   1.468e+02
# Food purchased from restaurants                    1.652e+02   1.659e+02
# Food                                               1.576e+02   1.580e+02
# ...                                                      ...         ...
# XTNTVA01CAM664N                                    3.780e+08   1.300e+09
# XTNTVA01CAM664S                                    1.129e+09   2.674e+09
# XTNTVA01CAM667S                                    9.018e+08   2.123e+09
# TOTALNS                                            4.276e+03   4.316e+03
# TOTALSL                                            4.324e+03   4.337e+03
#
#                                                   2021-09-01  2021-10-01
# Bakery and cereal products (excluding baby food)   1.581e+02   1.593e+02
# Dairy products and eggs                            1.480e+02   1.466e+02
# Fish, seafood and other marine products            1.471e+02   1.493e+02
# Food purchased from restaurants                    1.659e+02   1.671e+02
# Food                                               1.585e+02   1.592e+02
# ...                                                      ...         ...
# XTNTVA01CAM664N                                    1.561e+09   1.561e+09
# XTNTVA01CAM664S                                    2.277e+09   2.277e+09
# XTNTVA01CAM667S                                    1.798e+09   1.798e+09
# TOTALNS                                            4.347e+03   4.347e+03
# TOTALSL                                            4.367e+03   4.367e+03
#
# [332 rows x 430 columns]

# %% [markdown]
# ## Fit Models Using All Data To Produce Final Forecast

# %%
cutoff_date = foodprice_df.index[-1]  # Select the most recent date available.
prediction_length = 18

train_dates = foodprice_df.loc[foodprice_df.index <= cutoff_date].index

train_ds = ListDataset(
    [{'target': x, 'start': train_dates[0]} for x in dataset_df[list(train_dates)].values],
    freq='MS'
)

# Note: We need to add empty forecast dates since make_evaluation_predictions will cut off prediction_length many entries.
forecast_dates = pd.date_range(pd.to_datetime(cutoff_date) + pd.DateOffset(months=1), pd.to_datetime(cutoff_date) + pd.DateOffset(months=prediction_length), freq='MS')

extra_series = []
for date in forecast_dates:
    extra_series.append(pd.Series(np.zeros_like(dataset_df.index), name=date, index=dataset_df.index))

forecast_df = dataset_df.join(extra_series)

forecast_ds = ListDataset(
    [{'target': x, 'start': train_dates[0]} for x in forecast_df[list(train_dates) + list(forecast_dates)].values],
    freq='MS'
)

estimator = NBEATSEnsembleEstimator(
    prediction_length=prediction_length,
    meta_bagging_size = 3, 
    meta_context_length = [prediction_length * m for m in [3,5,7]], 
    meta_loss_function = ['sMAPE'], 
    num_stacks = 30,
    widths= [512],
    freq="MS",
    trainer=Trainer(
                epochs=100,
                num_batches_per_epoch=200,
                ctx=mx.context.cpu()
            )

)

predictor = estimator.train(train_ds)

forecast_it, ts_it = make_evaluation_predictions(
    dataset=forecast_ds,  # train dataset
    predictor=predictor,  # predictor
)

forecasts = list(forecast_it)

all_food_metrics = {}
food_forecasts = {}

for target_index in range(len(forecasts)):

    # Get food price category
    foodprice_category = foodprice_df.columns[target_index]

    if foodprice_category not in food_categories:
        continue

    # plot actual
    fig, ax = plt.subplots(figsize=(8,3))
    ax.plot(train_dates, foodprice_df[foodprice_category][train_dates], color='black')

    # plot forecast
    forecast_entry = forecasts[target_index]
    ax.plot(forecast_dates, forecast_entry.mean[:len(forecast_dates)], color='C0')

    plt.title(f"{foodprice_category}, October 2021 Forecast")
    plt.grid()
    plt.show()

    food_forecasts[foodprice_category] = pd.Series(forecast_entry.mean, index=forecast_dates, name=foodprice_category)

all_forecasts = pd.DataFrame(food_forecasts)
all_forecasts.to_csv(f"{output_path}/fc_final.csv")
# Out:
# /Users/ethan/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/dataset/common.py:323: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   timestamp = pd.Timestamp(string, freq=freq)
# /Users/ethan/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/dataset/common.py:326: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version
#   if isinstance(timestamp.freq, Tick):
# /Users/ethan/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/dataset/common.py:337: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version
#   return timestamp.freq.rollforward(timestamp)
# TRAINER:gluonts.mx.trainer._base.Trainer(add_default_callbacks=True, batch_size=None, callbacks=None, clip_gradient=10.0, ctx=mxnet.context.Context("cpu", 0), epochs=100, hybridize=True, init="xavier", learning_rate=0.001, learning_rate_decay_factor=0.5, minimum_learning_rate=5e-05, num_batches_per_epoch=200, patience=10, weight_decay=1e-08)
#   0%|          | 0/200 [00:00<?, ?it/s]/Users/ethan/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/transform/split.py:36: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version
#   return _shift_timestamp_helper(ts, ts.freq, offset)
# /Users/ethan/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/transform/split.py:36: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version
#   return _shift_timestamp_helper(ts, ts.freq, offset)
# 100%|██████████| 200/200 [00:45<00:00,  4.43it/s, epoch=1/100, avg_epoch_loss=3.02]
#   2%|▏         | 4/200 [00:00<00:44,  4.42it/s, epoch=2/100, avg_epoch_loss=3.38]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/fk/yggmcgc53hg46v7tyt18v44r0000gn/T/ipykernel_86680/3496175726.py in <module>
#      40 )
#      41
# ---> 42 predictor = estimator.train(train_ds)
#      43
#      44 forecast_it, ts_it = make_evaluation_predictions(
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/model/n_beats/_ensemble.py in train(self, training_data, validation_data)
#     443                 f"Training estimator {index + 1}/{len(self.estimators)}."
#     444             )
# --> 445             predictors.append(estimator.train(training_data, validation_data))
#     446
#     447         return NBEATSEnsemblePredictor(
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/mx/model/estimator.py in train(self, training_data, validation_data, num_workers, num_prefetch, shuffle_buffer_length, cache_data, **kwargs)
#     193         **kwargs,
#     194     ) -> Predictor:
# --> 195         return self.train_model(
#     196             training_data=training_data,
#     197             validation_data=validation_data,
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/mx/model/estimator.py in train_model(self, training_data, validation_data, num_workers, num_prefetch, shuffle_buffer_length, cache_data)
#     168         training_network = self.create_training_network()
#     169
# --> 170         self.trainer(
#     171             net=training_network,
#     172             train_iter=training_data_loader,
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/mx/trainer/_base.py in __call__(self, net, train_iter, validation_iter)
#     434                 logger.info(f"Epoch[{epoch_no}] Learning rate is {curr_lr}")
#     435
# --> 436                 epoch_loss = loop(
#     437                     epoch_no,
#     438                     train_iter,
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/mx/trainer/_base.py in loop(epoch_no, batch_iter, num_batches_to_use, is_training)
#     323
#     324                 it = tqdm(batch_iter, total=num_batches_to_use)
# --> 325                 for batch_no, batch in enumerate(it, start=1):
#     326                     # `batch` here is expected to be a dictionary whose fields
#     327                     # should correspond 1-to-1 with the network inputs
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/tqdm/std.py in __iter__(self)
#    1178
#    1179         try:
# -> 1180             for obj in iterable:
#    1181                 yield obj
#    1182                 # Update and possibly print the progressbar.
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/transform/_base.py in __iter__(self)
#     101
#     102     def __iter__(self) -> Iterator[DataEntry]:
# --> 103         yield from self.transformation(
#     104             self.base_dataset, is_train=self.is_train
#     105         )
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/transform/_base.py in __call__(self, data_it, is_train)
#     123         for data_entry in data_it:
#     124             try:
# --> 125                 yield self.map_transform(data_entry.copy(), is_train)
#     126             except Exception as e:
#     127                 raise e
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/transform/_base.py in map_transform(self, data, is_train)
#     138
#     139     def map_transform(self, data: DataEntry, is_train: bool) -> DataEntry:
# --> 140         return self.transform(data)
#     141
#     142     @abc.abstractmethod
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/transform/_base.py in transform(self, data)
#     157
#     158     def transform(self, data: DataEntry) -> DataEntry:
# --> 159         return self.func(data.copy())
#     160
#     161
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/mx/batchify.py in batchify(data, ctx, dtype, variable_length, is_right_pad)
#      76     is_right_pad: bool = True,
#      77 ) -> DataBatch:
# ---> 78     return {
#      79         key: stack(
#      80             data=[item[key] for item in data],
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/mx/batchify.py in <dictcomp>(.0)
#      77 ) -> DataBatch:
#      78     return {
# ---> 79         key: stack(
#      80             data=[item[key] for item in data],
#      81             ctx=ctx,
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/gluonts/mx/batchify.py in stack(data, ctx, dtype, variable_length, is_right_pad)
#      63         return mx.nd.stack(*data)
#      64     if isinstance(data[0], np.ndarray):
# ---> 65         data = mx.nd.array(data, dtype=dtype, ctx=ctx)
#      66     elif isinstance(data[0], (list, tuple)):
#      67         return list(stack(t, ctx=ctx) for t in zip(*data))
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/mxnet/ndarray/utils.py in array(source_array, ctx, dtype)
#     144         return _sparse_array(source_array, ctx=ctx, dtype=dtype)
#     145     else:
# --> 146         return _array(source_array, ctx=ctx, dtype=dtype)
#     147
#     148
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/mxnet/ndarray/ndarray.py in array(source_array, ctx, dtype)
#    3370     else:
#    3371         arr = empty(source_array.shape, ctx, dtype)
# -> 3372         arr[:] = source_array
#    3373         return arr
#    3374
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/mxnet/ndarray/ndarray.py in __setitem__(self, key, value)
#     544             indexing_dispatch_code = get_indexing_dispatch_code(slc_key)
#     545             if indexing_dispatch_code == _NDARRAY_BASIC_INDEXING:
# --> 546                 self._set_nd_basic_indexing(key, value)
#     547             elif indexing_dispatch_code == _NDARRAY_ADVANCED_INDEXING:
#     548                 self._set_nd_advanced_indexing(key, value)
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/mxnet/ndarray/ndarray.py in _set_nd_basic_indexing(self, key, value)
#     982             elif isinstance(value, (np.ndarray, np.generic)):
#     983                 tmp_shape = _shape_for_bcast(
# --> 984                     value.shape, target_ndim=self.ndim, new_axes=int_axes
#     985                 )
#     986                 value = value.reshape(tmp_shape)
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/mxnet/ndarray/ndarray.py in ndim(self)
#    2380         2
#    2381         """
# -> 2382         return len(self.shape)
#    2383
#    2384     @property
#
# ~/anaconda3/envs/foodprice/lib/python3.9/site-packages/mxnet/ndarray/ndarray.py in shape(self)
#    2401                 self.handle, ctypes.byref(ndim), ctypes.byref(pdata)))
#    2402         else:
# -> 2403             pdata = ctypes.POINTER(mx_int)()
#    2404             check_call(_LIB.MXNDArrayGetShapeEx(
#    2405                 self.handle, ctypes.byref(ndim), ctypes.byref(pdata)))
#
# KeyboardInterrupt:
