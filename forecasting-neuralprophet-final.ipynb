# %%
import pandas as pd
pd.set_option('precision', 3)

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
import os

import ast
import re

from neuralprophet import NeuralProphet

# %%
"""
Set sample rate. In this notebook, all data will be resampled at the chosen frequency.
'MS' : Monthly (Month Start)
'W' : Weekly
'D' : Daily
"""

year_period = {'MS': 12, 'W': 52, 'D': 365}
frequency = 'MS'
one_year = year_period[frequency]

# %% [markdown]
# ## Load Data From File

# %%
foodprice_categories = pd.read_csv("./foodprice_categories.txt", sep='\n', header=None)[0].to_list()
foodprice_df = pd.read_csv("./all_data.csv.bak", index_col=0)
foodprice_df = foodprice_df.set_index(pd.DatetimeIndex(foodprice_df.index))
foodprice_df
# Out:
#             Bakery and cereal products (excluding baby food)  \
# 1986-01-01                                              69.3
# 1986-02-01                                              70.3
# 1986-03-01                                              70.6
# 1986-04-01                                              71.3
# 1986-05-01                                              71.2
# ...                                                      ...
# 2021-06-01                                             157.7
# 2021-07-01                                             157.9
# 2021-08-01                                             158.5
# 2021-09-01                                             158.1
# 2021-10-01                                             159.3
#
#             Dairy products and eggs  Fish, seafood and other marine products  \
# 1986-01-01                     70.9                                     60.6
# 1986-02-01                     70.8                                     61.3
# 1986-03-01                     71.1                                     61.3
# 1986-04-01                     71.0                                     61.4
# 1986-05-01                     71.4                                     61.9
# ...                             ...                                      ...
# 2021-06-01                    145.3                                    146.2
# 2021-07-01                    146.4                                    146.6
# 2021-08-01                    148.3                                    146.8
# 2021-09-01                    148.0                                    147.1
# 2021-10-01                    146.6                                    149.3
#
#             Food purchased from restaurants   Food  \
# 1986-01-01                             59.1   67.3
# 1986-02-01                             59.1   66.9
# 1986-03-01                             59.3   67.0
# 1986-04-01                             59.7   67.7
# 1986-05-01                             59.9   68.2
# ...                                     ...    ...
# 2021-06-01                            163.9  156.8
# 2021-07-01                            165.2  157.6
# 2021-08-01                            165.9  158.0
# 2021-09-01                            165.9  158.5
# 2021-10-01                            167.1  159.2
#
#             Fruit, fruit preparations and nuts   Meat  \
# 1986-01-01                                76.0   65.1
# 1986-02-01                                77.6   64.2
# 1986-03-01                                79.2   64.2
# 1986-04-01                                82.2   63.6
# 1986-05-01                                83.5   64.0
# ...                                        ...    ...
# 2021-06-01                               144.5  176.7
# 2021-07-01                               141.7  180.9
# 2021-08-01                               142.5  182.1
# 2021-09-01                               141.5  184.8
# 2021-10-01                               141.7  187.1
#
#             Other food products and non-alcoholic beverages  \
# 1986-01-01                                             77.5
# 1986-02-01                                             78.1
# 1986-03-01                                             78.6
# 1986-04-01                                             79.5
# 1986-05-01                                             79.8
# ...                                                     ...
# 2021-06-01                                            142.2
# 2021-07-01                                            141.9
# 2021-08-01                                            141.7
# 2021-09-01                                            144.3
# 2021-10-01                                            144.4
#
#             Vegetables and vegetable preparations  DEXCAUS  ...  \
# 1986-01-01                                   76.0    1.392  ...
# 1986-02-01                                   68.4    1.392  ...
# 1986-03-01                                   66.2    1.392  ...
# 1986-04-01                                   71.1    1.392  ...
# 1986-05-01                                   75.3    1.377  ...
# ...                                           ...      ...  ...
# 2021-06-01                                  153.4    1.203  ...
# 2021-07-01                                  154.8    1.240  ...
# 2021-08-01                                  152.2    1.251  ...
# 2021-09-01                                  150.0    1.262  ...
# 2021-10-01                                  149.4    1.266  ...
#
#             XTIMVA01CAM657S  XTIMVA01CAM659S  XTIMVA01CAM664N  \
# 1986-01-01            3.644           12.051        9.368e+09
# 1986-02-01            1.965           16.745        9.495e+09
# 1986-03-01          -11.565            1.655        8.803e+09
# 1986-04-01           13.334           10.821        1.034e+10
# 1986-05-01           -4.236            6.160        9.598e+09
# ...                     ...              ...              ...
# 2021-06-01           -1.087           31.561        5.159e+10
# 2021-07-01            1.990           18.580        5.106e+10
# 2021-08-01           -2.312           14.723        5.245e+10
# 2021-09-01           -3.461            8.557        5.080e+10
# 2021-10-01           -3.461            8.557        5.080e+10
#
#             XTIMVA01CAM664S  XTIMVA01CAM667S  XTNTVA01CAM664N  \
# 1986-01-01        9.496e+09        6.749e+09        6.906e+08
# 1986-02-01        9.632e+09        6.881e+09       -9.880e+07
# 1986-03-01        8.529e+09        6.085e+09        9.138e+08
# 1986-04-01        9.569e+09        6.897e+09        3.470e+08
# 1986-05-01        9.091e+09        6.605e+09        7.013e+08
# ...                     ...              ...              ...
# 2021-06-01        4.979e+10        4.075e+10        3.661e+09
# 2021-07-01        5.205e+10        4.156e+10        3.780e+08
# 2021-08-01        5.115e+10        4.060e+10        1.300e+09
# 2021-09-01        4.965e+10        3.920e+10        1.561e+09
# 2021-10-01        4.965e+10        3.920e+10        1.561e+09
#
#             XTNTVA01CAM664S  XTNTVA01CAM667S   TOTALNS   TOTALSL
# 1986-01-01        1.052e+09        7.479e+08   607.369   605.703
# 1986-02-01        1.539e+08        1.099e+08   605.807   610.678
# 1986-03-01        9.079e+08        6.478e+08   606.799   613.377
# 1986-04-01        6.563e+08        4.730e+08   614.367   619.658
# 1986-05-01        6.893e+08        5.008e+08   621.915   625.820
# ...                     ...              ...       ...       ...
# 2021-06-01        3.111e+09        2.546e+09  4259.604  4307.137
# 2021-07-01        1.129e+09        9.018e+08  4276.202  4323.730
# 2021-08-01        2.674e+09        2.123e+09  4316.303  4337.489
# 2021-09-01        2.277e+09        1.798e+09  4346.662  4367.402
# 2021-10-01        2.277e+09        1.798e+09  4346.662  4367.402
#
# [430 rows x 332 columns]

# %%
def get_neuralprophet_df(foodprice_df, food_category, dates, lagged_regressor):
    prophet_df = pd.DataFrame({'ds': foodprice_df[food_category][dates].index, 
                           'y':foodprice_df[food_category].loc[foodprice_df.index][dates], 
                           lagged_regressor: foodprice_df[lagged_regressor].loc[foodprice_df.index][dates],
                          })
    prophet_df.reset_index(drop=True, inplace=True)

    return prophet_df

# %% [markdown]
# ## Fit Models Using All Data To Produce Final Forecast

# %%
def fit_final_forecast_model(foodprice_df, food_category, all_dates, lagged_regressor, nlags):
           
    train_model =NeuralProphet(n_forecasts =18,                          #initialize model
                                n_lags = nlags)
    
    print("for food category: ", food_category, "\n for lagged regressor: ", lagged_regressor)
    train_df = get_neuralprophet_df(foodprice_df, food_category, all_dates, str(lagged_regressor)) #select data

    train_model = train_model.add_lagged_regressor(names=[lagged_regressor])                   #lagged regressor to model
    train_model.fit(train_df, freq='MS')                                              #fit the model
    
                
    future = train_model.make_future_dataframe(train_df, periods=18)                #create the future period
    forecast = train_model.predict(future)                                     # Produce the future period forecast. 
    print("done forecast")
        
    
    return model, forecast

# %%
ensemble_file = pd.read_csv("./ensemble_models.csv")
ensemble_file['models'] = ensemble_file['models'].apply(lambda x: ast.literal_eval(x))
# print(ensemble_file)
d = ensemble_file.set_index('food_category').T.to_dict()
print(d)
# Out:
# {'Bakery and cereal products (excluding baby food)': {'models': ['neuralprophet_202110_IRLTLT01CAM156N_nlags_36', 'nbeatsfredvars_202110', 'neuralprophet_202110_CUSR0000SAF112_nlags_24']}, 'Dairy products and eggs': {'models': ['neuralprophet_202110_CUSR0000SAF112_nlags_48', 'nbeats_202110']}, 'Fish, seafood and other marine products': {'models': ['neuralprophet_202110_CUSR0000SAF113_nlags_48', 'nbeats_202110', 'neuralprophet_202110_QCAR368BIS_nlags_60']}, 'Food purchased from restaurants': {'models': ['nbeatsfredvars_202110', 'nbeats_202110', 'neuralprophet_202110_WILL5000IND_nlags_36']}, 'Food': {'models': ['nbeatsfredvars_202110', 'neuralprophet_202110_CUSR0000SAF112_nlags_24', 'neuralprophet_202110_IRLTLT01CAM156N_nlags_60']}, 'Fruit, fruit preparations and nuts': {'models': ['neuralprophet_202110_CUSR0000SAF112_nlags_24', 'neuralprophet_202110_CUSR0000SAF112_nlags_36', 'neuralprophet_202110_CPALCY01CAM661N_nlags_24']}, 'Meat': {'models': ['nbeatsfredvars_202110', 'neuralprophet_202110_CUSR0000SAF112_nlags_24', 'nbeats_202110']}, 'Other food products and non-alcoholic beverages': {'models': ['neuralprophet_202110_VXOCLS_nlags_36', 'neuralprophet_202110_CUSR0000SAF112_nlags_24', 'prophet_202110']}, 'Vegetables and vegetable preparations': {'models': ['neuralprophet_202110_DEXCAUS_nlags_24', 'neuralprophet_202110_WILL5000IND_nlags_60', 'neuralprophet_202110_CPGRLE01CAM657N_nlags_60']}}

# %%
# %%time
all_forecasts = {} 
count = 0
for key,value in d.items():
    for val in (value['models']):
        print("this is key ", key)
        if not val.startswith("neuralprophet"):
            print("ignoring bc not neuralprophet")
        else:
            exp = re.compile(r'.*_(.*)_nlags_(.*)')
            re_match = exp.match(val)
            lagged_reg = str(re_match.group(1))
            nlags = int(re_match.group(2))
            print(lagged_reg)
            
            model, forecast= fit_final_forecast_model(foodprice_df, key, foodprice_df.index, lagged_reg, nlags)
            all_forecasts[(key, lagged_reg, nlags)] = forecast
            
            print("----------------done--------  ", count, "-----------")
            count += 1
#         break
#     break
# Out:
# INFO - (NP.utils.set_auto_seasonalities) - Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 223
#   0%|          | 0/229 [00:00<?, ?it/s]
# this is key  Bakery and cereal products (excluding baby food)
# IRLTLT01CAM156N
# for food category:  Bakery and cereal products (excluding baby food)
#  for lagged regressor:  IRLTLT01CAM156N
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 4.83E-02, min: 3.26E-01
#   0%|          | 0/229 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\AppData\Local\Temp/ipykernel_16516/3341002555.py in fit_final_forecast_model(foodprice_df, food_category, all_dates, lagged_regressor, nlags)
#       8
#       9     train_model = train_model.add_lagged_regressor(names=[lagged_regressor])                   #lagged regressor to model
# ---> 10     train_model.fit(train_df, freq='MS')                                              #fit the model
#      11
#      12
#
# ~\anaconda3\lib\site-packages\neuralprophet\forecaster.py in fit(self, df, freq, validation_df, epochs, local_modeling, progress_bar, plot_live_loss, progress_print, minimal)
#     949                 metrics_df = None
#     950             else:
# --> 951                 metrics_df = self._train(df, progress_bar=progress_bar, plot_live_loss=plot_live_loss)
#     952
#     953         if epochs is not None:
#
# ~\anaconda3\lib\site-packages\neuralprophet\forecaster.py in _train(self, df, df_val, progress_bar, plot_live_loss, progress_print)
#     650
#     651         # set up data loader
# --> 652         loader = self._init_train_loader(df)
#     653
#     654         # set up Metrics
#
# ~\anaconda3\lib\site-packages\neuralprophet\forecaster.py in _init_train_loader(self, df)
#     514             self.model = self._init_model()  # needs to be called after set_auto_seasonalities
#     515         if self.config_train.learning_rate is None:
# --> 516             self.config_train.learning_rate = self.config_train.find_learning_rate(self.model, dataset)
#     517             log.info("lr-range-test selected learning rate: {:.2E}".format(self.config_train.learning_rate))
#     518         self.config_train.apply_train_speed(lr=True)
#
# ~\anaconda3\lib\site-packages\neuralprophet\configure.py in find_learning_rate(self, model, dataset, repeat)
#     138         lrs = []
#     139         for i in range(repeat):
# --> 140             lr = utils_torch.lr_range_test(
#     141                 model,
#     142                 dataset,
#
# ~\anaconda3\lib\site-packages\neuralprophet\utils_torch.py in lr_range_test(model, dataset, loss_func, optimizer, batch_size, num_iter, skip_start, skip_end, start_lr, end_lr, plot)
#      44     with utils.HiddenPrints():
#      45         lr_finder = LRFinder(model, lrtest_optimizer, loss_func)
# ---> 46         lr_finder.range_test(
#      47             lrtest_loader,
#      48             val_loader=lrtest_loader_val,
#
# ~\anaconda3\lib\site-packages\torch_lr_finder\lr_finder.py in range_test(self, train_loader, val_loader, start_lr, end_lr, num_iter, step_mode, smooth_f, diverge_th, accumulation_steps, non_blocking_transfer)
#     315         for iteration in tqdm(range(num_iter)):
#     316             # Train on batch and retrieve loss
# --> 317             loss = self._train_batch(
#     318                 train_iter,
#     319                 accumulation_steps,
#
# ~\anaconda3\lib\site-packages\torch_lr_finder\lr_finder.py in _train_batch(self, train_iter, accumulation_steps, non_blocking_transfer)
#     399                 total_loss += loss
#     400
# --> 401         self.optimizer.step()
#     402
#     403         return total_loss.item()
#
# ~\anaconda3\lib\site-packages\torch\optim\lr_scheduler.py in wrapper(*args, **kwargs)
#      63                 instance._step_count += 1
#      64                 wrapped = func.__get__(instance, cls)
# ---> 65                 return wrapped(*args, **kwargs)
#      66
#      67             # Note that the returned function here is no longer a bound method,
#
# ~\anaconda3\lib\site-packages\torch\optim\optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# ~\anaconda3\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~\anaconda3\lib\site-packages\torch\optim\adamw.py in step(self, closure)
#     135                 state_steps.append(state['step'])
#     136
# --> 137             F.adamw(params_with_grad,
#     138                     grads,
#     139                     exp_avgs,
#
# ~\anaconda3\lib\site-packages\torch\optim\_functional.py in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#     141         step_size = lr / bias_correction1
#     142
# --> 143         param.addcdiv_(exp_avg, denom, value=-step_size)
#     144
#     145
#
# KeyboardInterrupt:

# %%
for (food_category, lagged_reg, nlags), forecast_df in all_forecasts.items():
    all_forecasts_yhat = {}
    print(food_category, lagged_reg, nlags)
    
    all_yhats = []
    for yhat in ["yhat" + str(i) for i in range(1,19)]:
        all_yhats.append((forecast_df.loc[forecast_df[yhat].first_valid_index()][yhat]))  #get all yhats from forecast
    print("this is all yhats ", all_yhats)
    
    all_forecasts_yhat[(food_category)] = pd.Series(all_yhats)
    all_forecasts_yhat[(food_category)].index = pd.DatetimeIndex(forecast_df.ds[-18:])
    
    final_forecast_df = pd.DataFrame(all_forecasts_yhat)
    output_path = "./output/final_forecasts/" + food_category + "_" + str(lagged_reg) + "_nlags_" + str(nlags)
    if not os.path.exists(output_path):
        print("making new directory for: ", output_path)
        os.mkdir(output_path)
    else:
        print("already done")
    
    final_forecast_df.to_csv(f"{output_path}/fc_final.csv")
